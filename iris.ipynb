# %%
import pandas as pd
import os
from DecisionTree import DecisionClassifier



iris = pd.read_csv("iris.csv", header = 0, sep = ',', encoding = 'gbk')
X = iris.iloc[:, :-1]
y = iris.iloc[:, -1]
Xtrain = X.sample(frac = 0.8, random_state = 42, axis = 0, replace = False)
Xtest = X.drop(Xtrain.index, inplace = False)
ytrain = y.loc[Xtrain.index]
ytest = y.drop(Xtrain.index, inplace = False)

clf = DecisionClassifier(max_depth = 7, criterion = "id3")
clf.fit(Xtrain, ytrain, show_graph = True)

# %%
y_predict = clf.predict(Xtest) 
print('the predict values are', y_predict)
# Out:
# the predict values are 1      1.0
# 14     1.0
# 20     1.0
# 21     1.0
# 37     1.0
# 41     1.0
# 48     1.0
# 52     2.0
# 57     0.0
# 58     0.0
# 71     0.0
# 74     0.0
# 87     0.0
# 88     0.0
# 90     0.0
# 91     0.0
# 92     0.0
# 99     0.0
# 102    2.0
# 103    2.0
# 106    0.0
# 107    NaN
# 116    2.0
# 121    2.0
# 124    2.0
# 129    2.0
# 130    2.0
# 140    2.0
# 144    2.0
# 149    2.0
# dtype: float64

# %%
clf.score(X, y)
# Out:
# 0.98
